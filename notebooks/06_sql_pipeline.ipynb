# %% [markdown]
# # SQL Pipeline

# %%
import duckdb
import pandas as pd

# %%
# NOTE: Need to fix
# con = duckdb.connect('insolvency-data/insolvency.duckdb')  # persistent DB file
# Or: con = duckdb.connect()  for in-memory only

# NOTE: uncomment bottom line after cleaned osb data
# DuckDB can query CSVs directly — useful during exploration
# result = con.execute("SELECT * FROM 'data/processed/osb_clean.csv' LIMIT 5").df()
